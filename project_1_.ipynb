# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Дмитрий, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провел отличную работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Дмитрий, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделал огромную работу и проект получился впечатляющим:)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект еще лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# **Анализ игровой индустрии**
#
# **Описание проекта**
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# **Описание данных**
# `Name` — название игры
#
# `Platform` — платформа
#
# `Year_of_Release` — год выпуска
#
# `Genre` — жанр игры
#
# `NA_sales` — продажи в Северной Америке (миллионы проданных копий)
#
# `EU_sales` — продажи в Европе (миллионы проданных копий)
#
# `JP_sales` — продажи в Японии (миллионы проданных копий)
#
# `Other_sales` — продажи в других странах (миллионы проданных копий)
#
# `Critic_Score` — оценка критиков (максимум 100)
#
# `User_Score` — оценка пользователей (максимум 10)
#
# `Rating` — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).
# Эта ассоциация определяет рейтинг
# компьютерных игр и присваивает им подходящую возрастную категорию.
# Данные за 2016 год могут быть неполными
#
# **Задачи**
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
#
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# **Шаг 2. Подготовьте данные**
#
# - Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его   обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# **Шаг 3. Проведите исследовательский анализ данных**
# - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте               распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования     предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# - Не учитывайте в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму         рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - Соотнесите выводы с продажами игр на других платформах.
# - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и   низкими продажами?
#
# **Шаг 4. Составьте портрет пользователя каждого региона**
#
# - Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# **Шаг 5. Проверьте гипотезы**
#
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования»)       разные.
# - Задайте самостоятельно пороговое значение alpha.
# Поясните:
# - Как вы сформулировали нулевую и альтернативную гипотезы;
# - Какой критерий применили для проверки гипотез и почему.
#
# **Шаг 6. Напишите общий вывод**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Здорово, что написал введение, но проекту также нужно и название.  </div> ✔

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
#  Название для проекта лучше выбирать более осмысленное, кратко отражающее его суть. </div>

# %% [markdown]
# ***1. Импорт данных***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st


from datetime import datetime
from scipy import stats as st
from scipy.stats import ttest_ind

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что импортируешь все библиотеки в отдельной ячейке!  </div>

# %%
data = pd.read_csv('/datasets/games.csv')
display(data)
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
data.columns = data.columns.str.lower()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Смотрим типы значения для всех столбцов

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Как мы так сразу определили, что пропуски не получится заполнить?  </div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# с выводом поторопился

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ***2. подготовка данных***

# %%
data.dropna(subset=['year_of_release'], inplace=True) 
#data['year_of_release'] = data['year_of_release'].fillna(0)
data['year_of_release'] = data['year_of_release'].astype(int)

unique_years = data['year_of_release'].unique()
print(unique_years)
# Out:
# [2006 1985 2008 2009 1996 1989 1984 2005 1999 2007 2010 2013 2004 1990
#  1988 2002 2001 2011 1998 2015 2012 2014 1992 1997 1993 1994 1982 2016
#  2003 1986 2000 1995 1991 1981 1987 1980 1983]

# %% [markdown]
# Поменяли тип данных для годов выпуска игр для приобразования пришлось удалить пустые значения (259шт) это не очень много

# %%
data.loc[data['user_score'] == 'tbd','user_score'] = np.nan
data['user_score'] = data['user_score'].astype('float')

data['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Почему ты решил удалить пропуски в оценках пользователей? Так мы теряем более половины данных.
#
# </div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# не стал удалять данные

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Поменяли тип данных,  аббревиатура 'tbd' что означает рейтинг не определен. Можно просто заменить на nan

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Верное решение.</div>

# %%
data.drop_duplicates(subset=['name', 'platform', 'year_of_release'], inplace=True)
duplicates = data.duplicated(subset=['name', 'platform', 'year_of_release'])
num_duplicates = duplicates.sum()
print(num_duplicates)
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Также нужно обязательно сделать проверку на наличие неявных дубликатов (совпадающие по названию, платформе и году релиза одновременно).
#
# </div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# Удалил 2 неявных дубликата

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Еще тут можно использовать метод `DataFrame.sum` с аргументом `axis=1`</div>
#
# ```python
#
#         df['total_sum'] = df[['value_1', 'value_2', 'value_3', 'value_4']].sum(axis=1)
#
# ```

# %% [markdown]
# Сумарные продажи по всем регионам

# %%
def count_missing_values(data):
    missing_values = data.isnull().sum()
    return missing_values
missing_values_count = count_missing_values(data)
print(missing_values_count)
# Out:
# name                  1
# platform              0
# year_of_release       0
# genre                 1
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8462
# user_score         8982
# rating             6677
# total_sales           0
# dtype: int64

# %% [markdown]
# 1 пропуск в name и genre можно оставить, это не повлияет на анализ

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После этапа предобработки нужно сделать краткий резюмирующий вывод о проделанной работе.</div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# добавил вывод

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Вывод**
#
# В столбцах rating, critic_score, user_score много пропусков. С этим ничего не сделать, их нельзя заполеять средними или медианными, потому что оценки индивидуальны для каждой игры. Возможно эти данные появятся в будующем
#
# Добавил столбец ['total_sales'] с общим числом продаж
#
# Заменил значения 'tbd' на nan
#
# Поменял типы данных в некоторых столбцах и удалил немного строк с пропусками

# %% [markdown]
# ***3. исследование данных***

# %%
game_counts_by_year = data['year_of_release'].value_counts().sort_index()

# Создание столбчатой диаграммы
plt.figure(figsize=(12, 6))
plt.bar(game_counts_by_year.index, game_counts_by_year.values)
plt.title('Количество игр по годам выпуска')
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр')
plt.grid(True)
plt.xticks(game_counts_by_year.index, rotation=90)

# Показать диаграмму
plt.show()

# %% [markdown]
# Пожалуй самый важный период с 2005 по 2009 год. В этот промежуток времени выпускалось наибольшее количество игр

# %%
sales_on_platform = data.pivot_table(index='platform', values='total_sales', aggfunc='sum').sort_values(
    by='total_sales', ascending=False)

plt.figure(figsize=(13,4))
sns.barplot(x=sales_on_platform.index,y=sales_on_platform['total_sales'])
plt.title("Продажи по платформам за весь период")
plt.xlabel("Название платформы")
plt.ylabel("Количество продаж")
# Out:
# Text(0, 0.5, 'Количество продаж')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец ,что подписываешь графики и оси! </div>

# %% [markdown]
# Активный рост с 1999 по 2008. В топе настольные консоли PS2, X360, PS3
# средний срок жизни консоли 8 лет

# %%
platform_grouped = sales_on_platform.reset_index()
top_platforms_list = platform_grouped['platform'].unique()

#Построим распределения по годам для каждой платформы.
for platform in top_platforms_list:
    data[data['platform'] == platform].pivot_table(index='year_of_release', values='total_sales', aggfunc='sum').plot(
        kind='bar', figsize=(13,4))
    plt.title(platform)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Правильно, что использовал цикл</div>

# %% [markdown]
# В начале 2000 было большое разноообразие консолей но со временем их осталось гораздо меньше. В основном жизненный цикл платформы длится 8-10 лет.

# %%
# Группировка данных по платформе и году выпуска, суммируя мировые продажи
platform_sales_by_year = data.groupby(['platform', 'year_of_release'])['total_sales'].sum().reset_index()

# Выбор платформ с наибольшими суммарными продажами
top_platforms = platform_sales_by_year.groupby('platform')['total_sales'].sum().nlargest(5).index.tolist()

# Построение распределения продаж по годам для выбранных платформ
plt.figure(figsize=(22, 8))
for platform in top_platforms:
    platform_data = platform_sales_by_year[platform_sales_by_year['platform'] == platform]
    plt.plot(platform_data['year_of_release'], platform_data['total_sales'], label=platform)

plt.title('Распределение продаж за все года', fontsize=15)
plt.xlabel('Год выпуска', fontsize=12)
plt.ylabel('Мировые продажи', fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# 5 самых популярных платформ по проданным играм за всё время

# %%
platform_years = data.groupby('platform')['year_of_release'].agg(['min', 'max']).reset_index()
platform_years['years_active'] = platform_years['max'] - platform_years['min']
average_lifespan = platform_years['years_active'].mean()
top_platforms = platform_years.sort_values(by='years_active', ascending=False).head(5)

# %%
print(average_lifespan)
# Out:
# 7.612903225806452

# %%
print(platform_years[['platform', 'years_active']])
# Out:
#    platform  years_active
# 0      2600             9
# 1       3DO             1
# 2       3DS             5
# 3        DC            10
# 4        DS            28
# 5        GB            13
# 6       GBA             7
# 7        GC             6
# 8       GEN             4
# 9        GG             0
# 10      N64             6
# 11      NES            11
# 12       NG             3
# 13       PC            31
# 14     PCFX             0
# 15       PS             9
# 16      PS2            11
# 17      PS3            10
# 18      PS4             3
# 19      PSP            11
# 20      PSV             5
# 21      SAT             5
# 22      SCD             1
# 23     SNES             9
# 24     TG16             0
# 25       WS             2
# 26      Wii            10
# 27     WiiU             4
# 28     X360            11
# 29       XB             8
# 30     XOne             3

# %%
print(top_platforms[['platform', 'years_active']])
# Out:
#    platform  years_active
# 13       PC            31
# 4        DS            28
# 5        GB            13
# 28     X360            11
# 19      PSP            11

# %% [markdown]
# Средний цикл жизни платформ 7.6 лет
#
# маклимальный - PC (31год)
#
# минимальный -  PCFX и TG16 (0лет)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# ✔ Еще можно попробовать получить примерный срок жизни платформ с помощью расчетов.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
platform_sales = data.groupby('platform')['total_sales'].sum().reset_index()

# Шаг 2: Отсортируйте платформы по суммарным продажам
sorted_platforms = platform_sales.sort_values('total_sales', ascending=False)

# Выберите указанное количество потенциально прибыльных платформ
num_top_platforms = 3
potential_profitable_platforms = sorted_platforms.head(num_top_platforms)

# Создайте столбчатую диаграмму для суммарных продаж по платформам
colors = ['blue', 'orange', 'green']  # Список цветов
plt.figure(figsize=(12, 8))
plt.bar(potential_profitable_platforms['platform'], potential_profitable_platforms['total_sales'], color=colors)
plt.title('Суммарные продажи по платформам', fontsize=15)
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Мировые продажи', fontsize=12)
plt.show()

# %% [markdown]
# Имеется общая тенденция к падению, эти платформы самые прибыльные за всю историю

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Согласен с выбранным актуальным периодом! </div>

# %%
current_year = 2016
last_years_data = data[data['year_of_release'] >= current_year - 3]

# Вычисление суммарных продаж для каждой платформы
platform_sales = last_years_data.groupby('platform')['total_sales'].sum().reset_index()

# Сортировка платформ по суммарным продажам
sorted_platforms = platform_sales.sort_values('total_sales', ascending=False)

# Получение топ-лидирующих платформ
top_platforms = sorted_platforms.head(5)['platform'].tolist()

# Построение графика "ящик с усами" для каждой из топ-лидеров
plt.figure(figsize=(12, 8))
boxplot_data = []
labels = []
for i, platform in enumerate(top_platforms):
    platform_data = last_years_data[last_years_data['platform'] == platform]['total_sales']
    boxplot_data.append(platform_data)
    labels.append(f'Platform {i+1}')
    # Добавление названия платформы около каждого ящика
    plt.text(i+1, platform_data.median(), platform, ha='center', va='bottom')

plt.boxplot(boxplot_data, labels=labels)
plt.title('Глобальные продажи игр по платформам за последние 3 года', fontsize=15)
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Мировые продажи (миллионы)', fontsize=12)
plt.ylim(0, 3)
plt.show()

# %%
plt.figure(figsize=(12, 8))
boxplot_data = []
labels = []
for i, platform in enumerate(top_platforms):
    platform_data = last_years_data[last_years_data['platform'] == platform]['total_sales']
    boxplot_data.append(platform_data)
    labels.append(f'Platform {i+1}')
    # Добавление названия платформы около каждого ящика
    plt.text(i+1, platform_data.median(), platform, ha='center', va='bottom')

plt.boxplot(boxplot_data, labels=labels)
plt.title('Глобальные продажи игр по платформам за последние 3 года', fontsize=15)
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Мировые продажи (миллионы)', fontsize=12)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# ✔ Тут лучше построить две визуализации. Одну не ограничивая продажи, чтобы рассмотреть выбросы, а на другой ограничить диапазон значений продаж ,чтобы отчетливо рассмотреть сами боксплоты. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Яшик с усами по продажам самых популярных платформ

# %%
pivot_table = last_years_data.pivot_table(index='genre', values='total_sales', aggfunc='sum')

pivot_table = pivot_table.sort_values(by='total_sales', ascending=False)

fig, ax = plt.subplots(figsize=(10, 10))
colors = plt.cm.tab20c(range(len(pivot_table)))
bars = ax.bar(pivot_table.index, pivot_table['total_sales'], color=colors)

plt.xlabel('Жанр')
plt.ylabel('Общие продажи')
plt.title('Продажи по жанрам')

ax.set_xticklabels(pivot_table.index, rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_481/3598020203.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(pivot_table.index, rotation=90)

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# поменял круговую диаграмму на столбчатую

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Анализ на 2017**
#
# топ лидируюющих платформ за последние 3 года в которые стоит вложиться
# ['PS4', 'PS3', 'XOne', 'X360', 'WiiU']
#
# на всех платформмах наблюдается спад.
# В начале 2000 было большое разнообразие консолей но со временем их осталось гораздо меньше. В основном жизненный цикл платформы длится 8-10 лет.
#
# так же стоитт разрабатывать игры жанра shooter, action sports.Они щас популярны

# %%
#Уимнгожаем оценки для корректного сравнения 
last_years_data['user_score'] = last_years_data['user_score']*10
for platform in top_platforms:
    # Создание поднабора данных только для текущей платформы
    subset = last_years_data[last_years_data['platform'] == platform][['critic_score', 'user_score', 'total_sales']]
    
    # Удаление строк со значениями NaN
    subset = subset.dropna()
    
    # Вычисление корреляции
    correlation_critic = subset['critic_score'].corr(subset['total_sales'])
    correlation_user = subset['user_score'].corr(subset['total_sales'])
    
    print("Платформа:", platform)
    print("Корреляция с оценкой критиков:", correlation_critic)
    print("Корреляция с оценкой пользователей:", correlation_user)
    print("------------------------")
    
    # Построение диаграммы рассеяния
    plt.scatter(subset['critic_score'], subset['total_sales'], color='blue', label='Оценка критиков')
    plt.scatter(subset['user_score'], subset['total_sales'], color='green', label='Оценка пользователей')
    plt.xlabel('Оценки')
    plt.ylabel('Общие продажи (миллионы)')
    plt.legend()
    plt.show()
# Out:
# /tmp/ipykernel_481/224317746.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_years_data['user_score'] = last_years_data['user_score']*10
# Платформа: PS4
# Корреляция с оценкой критиков: 0.40589480145836687
# Корреляция с оценкой пользователей: -0.03362497596528888
# ------------------------
# Платформа: PS3
# Корреляция с оценкой критиков: 0.33380663565061736
# Корреляция с оценкой пользователей: 0.02269094327112415
# ------------------------
# Платформа: XOne
# Корреляция с оценкой критиков: 0.41042203561296375
# Корреляция с оценкой пользователей: -0.09400318326920865
# ------------------------
# Платформа: 3DS
# Корреляция с оценкой критиков: 0.3392349287853147
# Корреляция с оценкой пользователей: 0.2729904366942444
# ...

# %% [markdown]
# У PS4, Xbox One, WiiU, 3DS наблюдается связь между оценками критиков и продажами. А связь между оценками пользователей и продажами слабая у всех платформ, либо её совсем нет. Покупатели прислушиваются больше к критикам, чем к оценкам другим пользователей

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Зависимость продаж от оценок пользователей и критиков проанализирована верно! </div>

# %%
genre_sales = last_years_data.groupby('genre')['total_sales'].sum().reset_index()
genre_median_sales = last_years_data.groupby('genre')['total_sales'].median().reset_index()
genre_median_sales.columns = ['genre', 'median_sales']

genre_sales = pd.merge(genre_sales, genre_median_sales, on='genre')

sorted_genres = genre_sales.sort_values('median_sales', ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(data=sorted_genres, x='genre', y='median_sales')
plt.title('Median Sales of Games by Genre')
plt.xlabel('Genre')
plt.ylabel('Global Sales (millions)')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Самые прибыльные жанры: Shooter, Sports и Platform. Эти жанры выделяются своими высокими объёмами продаж.
#
# Жанры с низкими продажами: Strategy, Puzzle и Adventure . Эти жанры отличаются более низкими объемами продаж по сравнению с другими жанрами.
#
# Остальные жанры занимают промежуточные позиции по объему продаж

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Определять прибыльность жанров только по суммарным продажам не совсем корректно, нужно еще учитывать соотношение с количеством выпущенных игр. А лучше сразу рассматривать медианные значения продаж, они являются наиболее объективным показателем прибыльности, так как менее подвержены влиянию выбросов (а в игровой индустрии их достаточно много за счет продаж очень популярных и хитовых игр)</div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# переделал расчёты

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# 4. Портрет пользователя каждого региона

# %%
# Функция для создания сводных таблиц за последний период
def user_portrait(row, title):
    fig, axes = plt.subplots(1, 3, figsize=(20, 4))
    for pivot, ax in zip(list(['platform','genre','rating']),axes):
        ppivot = last_years_data.pivot_table(index=pivot, values=row, aggfunc='sum'
                  ).sort_values(by=row, ascending=False).reset_index().rename_axis(None, axis=1).head(5)
        display(ppivot)

        sns.set_palette("Blues")
        sns.barplot(data=ppivot, x=pivot, y=row, ax=ax)
        ax.set(xlabel=None, ylabel=None)  
        fig.suptitle(title, fontsize=15)

    plt.show()
    sns.set()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Круто, что пишешь функции! </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Строить портреты пользователей нам нужно также по актуальному периоду.
# </div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# убрал анализ за последний год

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
user_portrait('na_sales','Топ 5 платформ, жанров и рейтингов за  период')
# Out:
#   platform  na_sales
# 0      PS4    108.74
# 1     XOne     93.12
# 2     X360     81.66
# 3      PS3     63.50
# 4      3DS     38.20
#           genre  na_sales
# 0        Action    126.05
# 1       Shooter    109.74
# 2        Sports     65.27
# 3  Role-Playing     46.40
# 4          Misc     27.49
#   rating  na_sales
# 0      M    165.21
# 1      E     79.05
# 2   E10+     54.24
# 3      T     49.79

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Оси стоит подписывать на языке проекта. В данном случае подписи оси у вообще можно убрать и добавить название региона в заголовки.</div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# переделал вывод и убрал подписи на осях

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# А название региона забыл добавить в заголовок)</div>

# %%
user_portrait('eu_sales','Топ 5 платформ, жанров и рейтингов за период')
# Out:
#   platform  eu_sales
# 0      PS4    141.09
# 1      PS3     67.81
# 2     XOne     51.59
# 3     X360     42.52
# 4      3DS     30.96
#           genre  eu_sales
# 0        Action    118.13
# 1       Shooter     87.86
# 2        Sports     60.52
# 3  Role-Playing     36.97
# 4        Racing     20.19
#   rating  eu_sales
# 0      M    145.32
# 1      E     83.36
# 2   E10+     42.69
# 3      T     41.95

# %%
user_portrait('jp_sales','Топ 5 платформ, жанров и рейтингов за период')
# Out:
#   platform  jp_sales
# 0      3DS     67.81
# 1      PS3     23.35
# 2      PSV     18.59
# 3      PS4     15.96
# 4     WiiU     10.88
#           genre  jp_sales
# 0  Role-Playing     51.04
# 1        Action     40.49
# 2          Misc      9.20
# 3      Fighting      7.65
# 4       Shooter      6.61
#   rating  jp_sales
# 0      T     20.59
# 1      E     15.14
# 2      M     14.11
# 3   E10+      5.89

# %% [markdown]
# **Продажи по регионам за последние годы:**
#
# В Европе (EU) наибольшие продажи у PlayStation 4 (141.09 млн копий), за ним следует PlayStation 3 (67.81 млн копий).
# В Северной Америке (NA) лидирует PlayStation 4 (108.74 млн копий), а Xbox One занимает второе место (93.12 млн копий).
# В Японии (JP) самой популярной платформой остается Nintendo 3DS (67.81 млн копий), затем PlayStation 3 (23.35 млн копий).
# По жанрам игр:
#
# В Европе и Северной Америке наиболее популярными жанрами являются экшн и шутеры.
# В Японии преобладают ролевые игры, за которыми следуют экшн-игры и разные жанры.
# Рейтинг игр:
#
# Во всех трех регионах игры с рейтингом "M" (для взрослых) имеют наибольшие продажи.
# В Европе и Северной Америке также популярны игры с рейтингом "E" (для всех возрастов), а в Японии с рейтингом "T" (подросткам).

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А если заполнить пропуски в рейтингах каким-нибудь единым значением, означающим отсутствие рейтинга, то можно будет увидеть интересную особенность)</div>

# %% [markdown]
# ***5. Гипотезы***

# %%
last_years_data['platform'].unique()
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'XOne', 'WiiU', 'Wii', 'PC', 'PSV',
#        'DS', 'PSP'], dtype=object)

# %% [markdown]
# 5. Проверьте гипотезы

# %% [markdown]
# **Сформулируем нулевые гипотезы:**
#
# 1
# - Нулевая гипотеза H₀: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Альтернативная гипотеза H₁: Средние пользовательские рейтинги платформ Xbox One и PC различаются
#
# 2
# - Нулевая гипотеза H₀: Средние пользовательские рейтинги жанров Action и Sports одинаковые.
# - Альтернативная гипотеза H₁: Средние пользовательские рейтинги жанров Action и Sports различаются.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что формулируешь гипотезы вначале шага </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# ✔  Все библиотеки лучше импортировать в самом начале проекта, в отдельной ячейке. Если в процессе работы появилась необходимость добавить библиотеку, то ее можно дописать в эту ячейку и исполнить.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
def calculate_mean_and_test(data1, data2, label1, label2):
    mean1 = data1.mean()
    mean2 = data2.mean()
    
    alpha = 0.05
    results = st.ttest_ind(data1, data2, equal_var=False)
    p_value = results.pvalue
    
    print(f"Средний пользовательский рейтинг {label1}: {mean1}")
    print(f"Средний пользовательский рейтинг {label2}: {mean2}")
    
    print("p-значение:", p_value)
    
    if p_value < alpha:
        print("Отвергаем нулевую гипотезу")
    else:
        print("Не получилось отвергнуть нулевую гипотезу")
    
    print("---------------------------")

XOne = last_years_data[(last_years_data['platform'] == 'XOne') & (last_years_data['user_score'] > 0)]['user_score']
PC = last_years_data[(last_years_data['platform'] == 'PC') & (last_years_data['user_score'] > 0)]['user_score']

calculate_mean_and_test(XOne, PC, "платформы Xbox One", "платформы PC")

Action = last_years_data[(last_years_data['genre'] == 'Action') & (last_years_data['user_score'] > 0)]['user_score']
Sports = last_years_data[(last_years_data['genre'] == 'Sports') & (last_years_data['user_score'] > 0)]['user_score']

calculate_mean_and_test(Action, Sports, "жанра Action", "жанра Sports")
# Out:
# Средний пользовательский рейтинг платформы Xbox One: 65.21428571428571
# Средний пользовательский рейтинг платформы PC: 62.696774193548386
# p-значение: 0.1475959401343053
# Не получилось отвергнуть нулевую гипотезу
# ---------------------------
# Средний пользовательский рейтинг жанра Action: 68.37532133676092
# Средний пользовательский рейтинг жанра Sports: 52.38125
# p-значение: 1.446003970070494e-20
# Отвергаем нулевую гипотезу
# ---------------------------

# %% [markdown]
# **Вывод: 1** не получилось опровергнуть Нулевую гипотезу. нет достаточных доказательств для того, чтобы сделать вывод о наличии разницы между средними пользовательскими рейтингами платформ XOne и PC.
#
# **Вывод: 2** гипотеза подтвердилась. Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Вывод по первой гипотезе не соответствует полученным результатам.</div>

# %% [markdown]
# <div style="background-color:lavender; color:#black; text-align:center; padding:2%">
# переделал вывод

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **6. Вывод**
#
#
# **Общие данные**
#
# В период с 2005 по 2009 год было выпущено наибольшее количество игр. Этот период является важным для игровой индустрии.
# Жизненный цикл большинства платформ составляет около 7.6 лет. Максимальный жизненный цикл у PC, а минимальный у платформ PCFX и TG16.
#
# Наблюдается связь между оценками критиков и продажами на платформах PS4, Xbox One, WiiU и 3DS, в то время как связь между оценками пользователей и продажами слабая или отсутствует. Это означает, что потребители склонны больше прислушиваться к рекомендациям критиков при покупке игр.
#
#
# **Неизвестные значения**
#
# ббревиатура tbd значит to be determined, to be done. То есть, данные были нарочно не заполнены. Поэтому заменили tbd на nan
#
#
# **Прогнозы на 2017 год**
#
# Наблюдается спад продаж на всех платформах. Однако стоит обратить внимание на платформы PS4, PS3, XOne, X360 и WiiU, которые были лидерами за это время.
#
# Разработка игр в жанрах shooter, action и sports может быть перспективной, так как эти жанры в настоящее время популярны.
# скорее всего список консалолей останется не большим
#
#
# **Популярность в регионах**
#
# В Европе (EU) наибольшие продажи у PlayStation 4 (141.09 млн копий), за ним следует PlayStation 3 (67.81 млн копий).
# В Северной Америке (NA) лидирует PlayStation 4 (108.74 млн копий), а Xbox One занимает второе место (93.12 млн копий).
# В Японии (JP) самой популярной платформой остается Nintendo 3DS (67.81 млн копий), затем PlayStation 3 (23.35 млн копий).
# По жанрам игр:
#
# В Европе и Северной Америке наиболее популярными жанрами являются экшн и шутеры.
# В Японии преобладают ролевые игры, за которыми следуют экшн-игры и разные жанры.
# Рейтинг игр:
#
# Во всех трех регионах игры с рейтингом "M" (для взрослых) имеют наибольшие продажи.
# В Европе и Северной Америке также популярны игры с рейтингом "E" (для всех возрастов), а в Японии с рейтингом "T" (подросткам).
# Общий вывод: PlayStation 4 является одной из самых популярных платформ во всех трех регионах. В Европе и Северной Америке наиболее востребованы экшн-игры и шутеры, в то время как в Японии больше предпочитают ролевые игры. Игры с рейтингом "M" (для взрослых) имеют высокие продажи во всех регионах, но в Японии также популярны игры с рейтингом "T" (подросткам).
#
#
# **Гипотезы**
#
# В данном тесте используется t-тест для независимых выборок, который выполняется с помощью функции st.ttest_ind() из модуля scipy.stats.
# Как результат, функция выводит средние значения пользовательских рейтингов для каждой выборки, p-значение (вероятность получить такие или ещё более большие различия между выборками при условии, что нулевая гипотеза верна) и делает вывод о том, отвергается ли нулевая гипотеза о равенстве средних значений выборок.
#
# Поэтому в данном случае использовался t-тест для проверки статистической значимости различий между выборками.
#
# 1 гипотеза(Средние пользовательские рейтинги платформ Xbox One и PC одинаковые)
# - не получилось опровергнуть Нулевую гипотезу. нет достаточных доказательств для того, чтобы сделать вывод о наличии разницы       между средними пользовательскими рейтингами платформ XOne и PC.
#
# 2 гипотеза(Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.)
# - подтвердилась. Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Молодец, что не забыл дать рекомендации на 2017 год.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Вывод должен быть более подробным и содержать в себе информацию о том, какая работа была проделана на этапе предобработки и какие результаты получены в ходе исследования, то есть по всем пунктам.
#
# Человек, заинтересовавшийся твоим проектом, может сразу перейти к выводу, чтобы понять нужно ли ему углубляться в изучение исследования или нет.
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>
